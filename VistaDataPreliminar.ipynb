# %%
import pandas as pd

# %% [markdown]
# # DATA_RELACION_ENTIDADES_MAESTRO

# %%
data = pd.read_csv("DATA_RELACION_ENTIDADES_MAESTRO.csv", sep = ";")

# %%
data.head()
# Out:
#    Id_NIVEL_1  Id_NIVEL_0  ID_ENTIDAD_NIVEL_0  ID_ENTIDAD_NIVEL_1  \
# 0        2014         157                 157                2065
# 1        1126         880                 888                1145
# 2        1397         861                 869                1442
# 3         463         244                 246                 468
# 4         981         237                 239                 995
#
#           Jerarquia NIF_COD_NIVEL_0 ACRONIMO_NIVEL_0  \
# 0       Nodos_ciber            None       INB ISCIII
# 1  Orgánica Directa       Q5018001G           UNIZAR
# 2  Orgánica Directa       Q3018001B               UM
# 3  Orgánica Directa       Q2827015E           ISCIII
# 4  Orgánica Directa       Q2818002D             CSIC
#
#                               NOMBRE_ENTIDAD_NIVEL_0  \
# 0           INSTITUTO NACIONAL DE BIOINFORMATICA INB
# 1                            Universidad de Zaragoza
# 2                              Universidad de Murcia
# ...

# %% [markdown]
# # DATA_SIC_ENTIDADES_PUBLICAS_AYUDAS_ESP

# %%
data1 = pd.read_csv("DATA_SIC_ENTIDADES_PUBLICAS_AYUDAS_ESP.csv", sep = ";")

# %%
data1.head(10)
# Out:
#      Id        CIF                                       Entidad_Norm  \
# 0  2668  A36924140                              marine instruments sa
# 1  4782  B10398931                                controla energia sl
# 2  4589  A58567918                                         optral s a
# 3  3515  A39074877                                       apia xxi s a
# 4  2891  A41204223               gabinete de iniciativas europeas s a
# 5  7281  B47485859                                         legaris sl
# 6  2635  R0600001B  arzobispado merida badajoz archivos eclesiasticos
# 7   547  S4600111A                               val space consortium
# 8   352        NaN                instituto de agricultura sostenible
# 9  8193  B57780959                                sciware systems s l
#
#    Provincia_Entidad  ID_ENTIDAD    NIF_COD ACRONIMO  \
# 0               36.0         NaN        NaN      NaN
# 1               10.0         NaN        NaN      NaN
# ...

# %% [markdown]
# # DIR3_concatenado_AGE_CCAA_EELL_Universidades

# %%
data2 = pd.read_csv("DIR3_concatenado_AGE_CCAA_EELL_Universidades.csv", sep = ";")
# Out:
# /Users/arturo/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (17,18) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data2.head()
# Out:
#    Unnamed: 0 C_ID_UD_ORGANICA               C_DNM_UD_ORGANICA  \
# 0         NaN        E00003301           Ministerio de Defensa
# 1         NaN        E00115201  S.Gral. de Politica de Defensa
# 2         NaN        E00115401         Secretaria del Ministro
# 3         NaN        E00115501           Gabinete del Ministro
# 4         NaN        E00115601   Gabinete Tecnico del Ministro
#
#    C_ID_NIVEL_ADMON C_ID_TIPO_ENT_PUBLICA  N_NIVEL_JERARQUICO  \
# 0                 1                    MN                   1
# 1                 1                    MN                   2
# 2                 1                    MN                   2
# 3                 1                    MN                   2
# 4                 1                    MN                   2
#
#   C_ID_DEP_UD_SUPERIOR C_DNM_UD_ORGANICA_SUPERIOR C_ID_DEP_UD_PRINCIPAL  \
# 0            EA9999999  Administracion del Estado             E00003301
# ...

# %% [markdown]
# # MUNICIPIO_PROVINCIA_COMAS

# %%
data3 = pd.read_csv("MUNICIPIO_PROVINCIA_COMAS.csv", sep = ",")

# %%
data3.head()
# Out:
#    PROVINCIA NOMBRE_PROVINCIA  CMUN  DC     NOMBRE_MUNICIPIO
# 0          1      Araba/Álava    51   3  Agurain/Salvatierra
# 1          1      Araba/Álava     1   4     Alegría-Dulantzi
# 2          1      Araba/Álava     2   9              Amurrio
# 3          1      Araba/Álava    49   3                Añana
# 4          1      Araba/Álava     3   5              Aramaio

# %% [markdown]
# # Analisis_entidades_invente_15-02-2022

# %%
data4 = pd.read_excel("Analisis_entidades_invente_15-02-2022.xlsx", header = 1)

# %%
data4.head()
# Out:
#   CodigoInvente                                 DenominacionSocial  \
# 0   INV00000002                      1908 Puerto de Motril, A.I.E.
# 1   INV00000004  A.I. Abra Industrial, S.A. Sociedad Mercantil ...
# 2   INV00000006                               AAA Dominicana, S.A.
# 3   INV00000007                               AAA Venezuela, S.A.
# 4   INV00000008                         AAA. Ecuador Agacase, S.A.
#
#    FormaJuridica_Codigo FormaJuridica_Descripcion        NIF codigoDir3  \
# 0                    12       Sociedad mercantil   V18862987        NaN
# 1                    12       Sociedad mercantil   A48021349  EA0023191
# 2                    12       Sociedad mercantil         NaN        NaN
# 3                    12       Sociedad mercantil         NaN        NaN
# 4                    12       Sociedad mercantil         NaN        NaN
#
#    codigoOrigen CodigoInvente.1                 EjerceControl  \
# 0  0100000XP172     INV00000002        Administración Central
# ...
